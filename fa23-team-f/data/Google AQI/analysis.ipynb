# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

mdata = pd.read_csv("result.csv")

mdata['Total_PM'] = mdata['PM2.5'] + mdata['PM10']

plt.figure(figsize=(12, 6))
sns.barplot(x='Name', y='Total_PM', data=mdata, color='green')
plt.xlabel('Neighborhood')
plt.ylabel('Total PM (PM2.5 + PM10)')
plt.title('Total PM (PM2.5 + PM10) per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

mdata = pd.read_csv("result.csv")

plt.figure(figsize=(12, 6))
sns.barplot(x='Name', y='AQI', data=mdata, color='orange')
plt.xlabel('Neighborhood')
plt.ylabel('AQI')
plt.title('Total AQI per Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %%
mdata.head()
# Out:
#           Name  TotChild  OlderAdult  MedIllnes   POC2    LEP  Low_to_No  \
# 0      Allston       173         144    2831.85   3011   3444       3300
# 1     Back Bay      1686        3759   11842.96   6923   9075       5316
# 2  Bay Village      1249        1711    4292.93   6008   5640       3929
# 3     Brighton      4244        5847   23936.80  19768  22914      17067
# 4  Charlestown      3301        1811    6461.47   3981   5968       4157
#
#    TotDis  MBTA_Stops_Count        NO2         O3       PM10      PM2.5  \
# 0     400                 4  24.231629  19.906124  27.688315  10.316910
# 1    1892                 6  25.369122  19.696353  25.851348  11.155996
# 2    1122                 7  25.223408  19.764251  32.988801   8.177996
# 3    5502                 8  23.221051  20.088684  26.907099  10.012761
# 4    1535                 2  16.956124  20.362060  16.986386   8.215375
#
#         SO2  aqi  category  ZipCode
# 0  0.232022  NaN       NaN     2134
# 1  0.271823  NaN       NaN     2116
# 2  0.300487  NaN       NaN     2116
# 3  0.249334  NaN       NaN     2135
# 4  0.260150  NaN       NaN     2222
