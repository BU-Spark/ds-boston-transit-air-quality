# %%
import pandas as pd
import folium

result = pd.read_csv('resultneighborhood.csv')


neighborhood_data = {
    'Allston': (42.3555, -71.1328),
    'Brighton': (42.3501, -71.1627),
    'Dorchester': (42.3016, -71.0676),
    'Back Bay': (42.3503, -71.0810),
    'Bay Village': (42.3482, -71.0696),
    'South End': (42.3413, -71.0772),
    'North End': (42.3647, -71.0542),
    'East Boston': (42.3751, -71.0395),
    'Fenway': (42.3431, -71.1002),
    'Mission Hill': (42.3319, -71.1062),
    'Longwood Medical Area': (42.3389, -71.1098),
    'Hyde Park': (42.2566, -71.1245),
    'West Roxbury': (42.2798, -71.1627),
    'Jamaica Plain': (42.3097, -71.1151),
    'Mattapan': (42.2724, -71.0860),
    'Roslindale': (42.2814, -71.1371),
    'Roxbury': (42.3248, -71.0950),
    'South Boston': (42.3334, -71.0495)
}

df = pd.DataFrame(list(neighborhood_data.items()), columns=['Name', 'Coordinates'])
df[['Latitude', 'Longitude']] = pd.DataFrame(df['Coordinates'].tolist(), index=df.index)
df = df.drop('Coordinates', axis=1)
merged_df = pd.merge(df, result, on='Name', how='inner')


merged_df.head()

merged_df.columns

m = folium.Map(location=[42.3601, -71.0589], zoom_start=10)

for index, row in merged_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        tooltip=f"Neighborhood: {row['Name']}<br>"
                f"TotChild: {row['TotChild']}<br>"
                f"OlderAdult: {row['OlderAdult']}<br>"
                f"MedIllnes: {row['MedIllnes']}<br>"
                f"POC2: {row['POC2']}<br>"
                f"LEP: {row['LEP']}<br>"
                f"Low_to_No: {row['Low_to_No']}<br>"
                f"TotDis: {row['TotDis']}<br>"
                f"MBTA_Stops_Count: {row['MBTA_Stops_Count']}<br>"
                f"NO2: {row['NO2']}<br>"
                f"O3: {row['O3']}<br>"
                f"PM10: {row['PM10']}<br>"
                f"PM2.5: {row['PM2.5']}<br>"
                f"SO2: {row['SO2']}<br>"
                f"AQI: {row['AQI']}<br>"
                f"Category: {row['Category']}<br>"
                f"Bus_Stops_Count: {row['Bus_Stops_Count']}<br>"
                f"Blue_Bikes_Stations_Count: {row['Blue_Bikes_Stations_Count']}<br>"
                f"Blue_Bikes_Docks_Count: {row['Blue_Bikes_Docks_Count']}<br>"
                f"ZipCode: {row['ZipCode']}<br>"
                f"Transit_Stops: {row['Transit_Stops']}<br>"
                f"Number of Open Spaces: {row['Number of Open Spaces']}<br>"
                f"CASTHMA_CrudePrev: {row['CASTHMA_CrudePrev']}<br>"
                f"COPD_CrudePrev: {row['COPD_CrudePrev']}<br>"
                f"CHD_CrudePrev: {row['CHD_CrudePrev']}<br>"
                f"STROKE_CrudePrev: {row['STROKE_CrudePrev']}<br>"
                f"HIGHCHOL_CrudePrev: {row['HIGHCHOL_CrudePrev']}<br>"
                f"GHLTH_CrudePrev: {row['GHLTH_CrudePrev']}<br>"
                f"PHLTH_CrudePrev: {row['PHLTH_CrudePrev']}<br>"
                f"MHLTH_CrudePrev: {row['MHLTH_CrudePrev']}<br>"
                f"CSMOKING_CrudePrev: {row['CSMOKING_CrudePrev']}<br>"
                f"BINGE_CrudePrev: {row['BINGE_CrudePrev']}<br>"
                f"LPA_CrudePrev: {row['LPA_CrudePrev']}<br>"
                f"OBESITY_CrudePrev: {row['OBESITY_CrudePrev']}<br>"
                f"SLEEP_CrudePrev: {row['SLEEP_CrudePrev']}<br>"
                f"Num Parks: {row['NumParks']}<br>"
                f"Payroll Jobs: {row['Payroll Jobs']}<br>"
                f"Labor Force: {row['Labor Force']}<br>"
                f"At least one vehicle (%): {row['At least one vehicle (%)']}<br>"
                f"Vehicles to Households Ratio: {row['Vehicles to Households Ratio']}<br>",
    ).add_to(m)

# Save the map
m.save('neighborhood_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2ca18fd3bcfacf361367564672f5243 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2ca18fd3bcfacf361367564672f5243&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2ca18fd3bcfacf361367564672f5243 = L.map(
#                 &quot;map_d2ca18fd3bcfacf361367564672f5243&quot;,
#                 {
#                     center: [42.3601, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0dea27f97db3fa4fe0010987af8ad2c3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2ca18fd3bcfacf361367564672f5243);
#
#
#             var marker_65ef49537adb640510cdd9708ebbec07 = L.marker(
#                 [42.3555, -71.1328],
#                 {}
#             ).addTo(map_d2ca18fd3bcfacf361367564672f5243);
#
#
#             marker_65ef49537adb640510cdd9708ebbec07.bindTooltip(
#                 `&lt;div&gt;
#                      Neighborhood: Allston&lt;br&gt;TotChild: 173&lt;br&gt;OlderAdult: 144&lt;br&gt;MedIllnes: 2831.85&lt;br&gt;POC2: 3011&lt;br&gt;LEP: 3444&lt;br&gt;Low_to_No: 3300&lt;br&gt;TotDis: 400&lt;br&gt;MBTA_Stops_Count: 4&lt;br&gt;NO2: 24.231629213483146&lt;br&gt;O3: 19.90612359550562&lt;br&gt;PM10: 27.68831460674157&lt;br&gt;PM2.5: 10.316910112359553&lt;br&gt;SO2: 0.2320224719101123&lt;br&gt;AQI: 41.59550561797753&lt;br&gt;Category: Good air quality&lt;br&gt;Bus_Stops_Count: 9&lt;br&gt;Blue_Bikes_Stations_Count: 2&lt;br&gt;Blue_Bikes_Docks_Count: 30&lt;br&gt;ZipCode: 2134&lt;br&gt;Transit_Stops: 13&lt;br&gt;Number of Open Spaces: 39&lt;br&gt;CASTHMA_CrudePrev: 10.6&lt;br&gt;COPD_CrudePrev: 2.9&lt;br&gt;CHD_CrudePrev: 2.2&lt;br&gt;STROKE_CrudePrev: 1.2&lt;br&gt;HIGHCHOL_CrudePrev: 20.6&lt;br&gt;GHLTH_CrudePrev: 8.9&lt;br&gt;PHLTH_CrudePrev: 6.1&lt;br&gt;MHLTH_CrudePrev: 17.8&lt;br&gt;CSMOKING_CrudePrev: 8.8&lt;br&gt;BINGE_CrudePrev: 22.8&lt;br&gt;LPA_CrudePrev: 17.0&lt;br&gt;OBESITY_CrudePrev: 18.3&lt;br&gt;SLEEP_CrudePrev: 29.5&lt;br&gt;Num Parks 9&lt;br&gt;Payroll Jobs 16522&lt;br&gt;Labor Force 11478&lt;br&gt;At least one vehicle (%) 53&lt;br&gt;Vehicles to Households Ratio: 0.61&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8f86d420212b161f346303370bae511d = L.marker(
#                 [42.3501, -71.1627],
#                 {}
#             ).addTo(map_d2ca18fd3bcfacf361367564672f5243);
#
#
#             marker_8f86d420212b161f346303370bae511d.bindTooltip(
#                 `&lt;div&gt;
#                      Neighborhood: Brighton&lt;br&gt;TotChild: 4244&lt;br&gt;OlderAdult: 5847&lt;br&gt;MedIllnes: 23936.8&lt;br&gt;POC2: 19768&lt;br&gt;LEP: 22914&lt;br&gt;Low_to_No: 17067&lt;br&gt;TotDis: 5502&lt;br&gt;MBTA_Stops_Count: 8&lt;br&gt;NO2: 23.221051364365973&lt;br&gt;O3: 20.08868378812199&lt;br&gt;PM10: 26.907098715890843&lt;br&gt;PM2.5: 10.012760834670946&lt;br&gt;SO2: 0.2493338683788121&lt;br&gt;AQI: 39.829454253611566&lt;br&gt;Category: Good air quality&lt;br&gt;Bus_Stops_Count: 141&lt;br&gt;Blue_Bikes_Stations_Count: 18&lt;br&gt;Blue_Bikes_Docks_Count: 302&lt;br&gt;ZipCode: 2135&lt;br&gt;Transit_Stops: 149&lt;br&gt;Number of Open Spaces: 39&lt;br&gt;CASTHMA_CrudePrev: 10.5&lt;br&gt;COPD_CrudePrev: 3.5&lt;br&gt;CHD_CrudePrev: 3.2&lt;br&gt;STROKE_CrudePrev: 1.6&lt;br&gt;HIGHCHOL_CrudePrev: 24.3&lt;br&gt;GHLTH_CrudePrev: 8.9&lt;br&gt;PHLTH_CrudePrev: 6.5&lt;br&gt;MHLTH_CrudePrev: 16.2&lt;br&gt;CSMOKING_CrudePrev: 8.6&lt;br&gt;BINGE_CrudePrev: 22.3&lt;br&gt;LPA_CrudePrev: 16.8&lt;br&gt;OBESITY_CrudePrev: 18.6&lt;br&gt;SLEEP_CrudePrev: 28.7&lt;br&gt;Num Parks 13&lt;br&gt;Payroll Jobs 16860&lt;br&gt;Labor Force 28825&lt;br&gt;At least one vehicle (%) 68&lt;br&gt;Vehicles to Households Ratio: 1.02&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_87d7c59658f4b8bdfdfcca1ff34fc7ab = L.marker(
#                 [42.3016, -71.0676],
#                 {}
#             ).addTo(map_d2ca18fd3bcfacf361367564672f5243);
#
#
#             marker_87d7c59658f4b8bdfdfcca1ff34fc7ab.bindTooltip(
#                 `&lt;div&gt;
#                      Neighborhood: Dorchester&lt;br&gt;TotChild: 17424&lt;br&gt;OlderAdult: 6535&lt;br&gt;MedIllnes: 25010.76&lt;br&gt;POC2: 50778&lt;br&gt;LEP: 29284&lt;br&gt;Low_to_No: 22749&lt;br&gt;TotDis: 9819&lt;br&gt;MBTA_Stops_Count: 3&lt;br&gt;NO2: 21.24061206386753&lt;br&gt;O3: 20.798101714961565&lt;br&gt;PM10: 21.226487285629805&lt;br&gt;PM2.5: 9.759450029568304&lt;br&gt;SO2: 0.4019071555292726&lt;br&gt;AQI: 38.7495564754583&lt;br&gt;Category: Good air quality&lt;br&gt;Bus_Stops_Count: 199&lt;br&gt;Blue_Bikes_Stations_Count: 20&

# %%
import pandas as pd
import folium

result = pd.read_csv('resultneighborhood.csv')


neighborhood_data = {
    'Allston': (42.3555, -71.1328),
    'Brighton': (42.3501, -71.1627),
    'Dorchester': (42.3016, -71.0676),
    'Back Bay': (42.3503, -71.0810),
    'Bay Village': (42.3482, -71.0696),
    'South End': (42.3413, -71.0772),
    'North End': (42.3647, -71.0542),
    'East Boston': (42.3751, -71.0395),
    'Fenway': (42.3431, -71.1002),
    'Mission Hill': (42.3319, -71.1062),
    'Longwood Medical Area': (42.3389, -71.1098),
    'Hyde Park': (42.2566, -71.1245),
    'West Roxbury': (42.2798, -71.1627),
    'Jamaica Plain': (42.3097, -71.1151),
    'Mattapan': (42.2724, -71.0860),
    'Roslindale': (42.2814, -71.1371),
    'Roxbury': (42.3248, -71.0950),
    'South Boston': (42.3334, -71.0495)
}

df = pd.DataFrame(list(neighborhood_data.items()), columns=['Name', 'Coordinates'])
df[['Latitude', 'Longitude']] = pd.DataFrame(df['Coordinates'].tolist(), index=df.index)
df = df.drop('Coordinates', axis=1)
merged_df = pd.merge(df, result, on='Name', how='inner')


merged_df.head()

merged_df.columns


m = folium.Map(location=[42.3601, -71.0589], zoom_start=10)

def create_tooltip(row):
    tooltip = f"""
    <div style="max-height: 300px; overflow-y: auto;">
        <h4>{row['Name']}</h4>
        <b>Demographic Information:</b><br>
        TotChild: {row['TotChild']}<br>
        OlderAdult: {row['OlderAdult']}<br>
        MedIllnes: {row['MedIllnes']}<br>
        POC2: {row['POC2']}<br>
        LEP: {row['LEP']}<br>
        Low_to_No: {row['Low_to_No']}<br>
        TotDis: {row['TotDis']}<br>
        <br>
        <b>Environmental Information:</b><br>
        NO2: {row['NO2']}<br>
        O3: {row['O3']}<br>
        PM10: {row['PM10']}<br>
        PM2.5: {row['PM2.5']}<br>
        SO2: {row['SO2']}<br>
        AQI: {row['AQI']}<br>
        Category: {row['Category']}<br>
        <br>
        <b>Transportation Information:</b><br>
        Bus Stops Count: {row['Bus_Stops_Count']}<br>
        Blue Bikes Stations Count: {row['Blue_Bikes_Stations_Count']}<br>
        Blue Bikes Docks Count: {row['Blue_Bikes_Docks_Count']}<br>
        <br>
        <b>Health Information:</b><br>
        CASTHMA CrudePrev: {row['CASTHMA_CrudePrev']}<br>
        COPD CrudePrev: {row['COPD_CrudePrev']}<br>
        CHD CrudePrev: {row['CHD_CrudePrev']}<br>
        STROKE CrudePrev: {row['STROKE_CrudePrev']}<br>
        HIGHCHOL CrudePrev: {row['HIGHCHOL_CrudePrev']}<br>
        GHLTH CrudePrev: {row['GHLTH_CrudePrev']}<br>
        PHLTH CrudePrev: {row['PHLTH_CrudePrev']}<br>
        MHLTH CrudePrev: {row['MHLTH_CrudePrev']}<br>
        CSMOKING CrudePrev: {row['CSMOKING_CrudePrev']}<br>
        BINGE CrudePrev: {row['BINGE_CrudePrev']}<br>
        LPA CrudePrev: {row['LPA_CrudePrev']}<br>
        OBESITY CrudePrev: {row['OBESITY_CrudePrev']}<br>
        SLEEP CrudePrev: {row['SLEEP_CrudePrev']}<br>
        <br>
        <b>Other Information:</b><br>
        Num Parks: {row['NumParks']}<br>
        Payroll Jobs: {row['Payroll Jobs']}<br>
        Labor Force: {row['Labor Force']}<br>
        At least one vehicle (%): {row['At least one vehicle (%)']}<br>
        Vehicles to Households Ratio: {row['Vehicles to Households Ratio']}<br>
    </div>
    """
    return tooltip

for _, row in merged_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        tooltip=folium.Tooltip(text=create_tooltip(row), sticky=True),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f8256a5e3db6afedc58da5df544ab58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f8256a5e3db6afedc58da5df544ab58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f8256a5e3db6afedc58da5df544ab58 = L.map(
#                 &quot;map_9f8256a5e3db6afedc58da5df544ab58&quot;,
#                 {
#                     center: [42.3601, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_441501db7105d08a97a7d6074ab75b37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f8256a5e3db6afedc58da5df544ab58);
#
#
#             var marker_baaae458c9e2e8911063a0eea9b71753 = L.marker(
#                 [42.3555, -71.1328],
#                 {}
#             ).addTo(map_9f8256a5e3db6afedc58da5df544ab58);
#
#
#             marker_baaae458c9e2e8911063a0eea9b71753.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;div style=&quot;max-height: 300px; overflow-y: auto;&quot;&gt;
#         &lt;h4&gt;Allston&lt;/h4&gt;
#         &lt;b&gt;Demographic Information:&lt;/b&gt;&lt;br&gt;
#         TotChild: 173&lt;br&gt;
#         OlderAdult: 144&lt;br&gt;
#         MedIllnes: 2831.85&lt;br&gt;
#         POC2: 3011&lt;br&gt;
#         LEP: 3444&lt;br&gt;
#         Low_to_No: 3300&lt;br&gt;
#         TotDis: 400&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Environmental Information:&lt;/b&gt;&lt;br&gt;
#         NO2: 24.231629213483146&lt;br&gt;
#         O3: 19.90612359550562&lt;br&gt;
#         PM10: 27.68831460674157&lt;br&gt;
#         PM2.5: 10.316910112359553&lt;br&gt;
#         SO2: 0.2320224719101123&lt;br&gt;
#         AQI: 41.59550561797753&lt;br&gt;
#         Category: Good air quality&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Transportation Information:&lt;/b&gt;&lt;br&gt;
#         Bus Stops Count: 9&lt;br&gt;
#         Blue Bikes Stations Count: 2&lt;br&gt;
#         Blue Bikes Docks Count: 30&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Health Information:&lt;/b&gt;&lt;br&gt;
#         CASTHMA CrudePrev: 10.6&lt;br&gt;
#         COPD CrudePrev: 2.9&lt;br&gt;
#         CHD CrudePrev: 2.2&lt;br&gt;
#         STROKE CrudePrev: 1.2&lt;br&gt;
#         HIGHCHOL CrudePrev: 20.6&lt;br&gt;
#         GHLTH CrudePrev: 8.9&lt;br&gt;
#         PHLTH CrudePrev: 6.1&lt;br&gt;
#         MHLTH CrudePrev: 17.8&lt;br&gt;
#         CSMOKING CrudePrev: 8.8&lt;br&gt;
#         BINGE CrudePrev: 22.8&lt;br&gt;
#         LPA CrudePrev: 17.0&lt;br&gt;
#         OBESITY CrudePrev: 18.3&lt;br&gt;
#         SLEEP CrudePrev: 29.5&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Other Information:&lt;/b&gt;&lt;br&gt;
#         Num Parks: 9&lt;br&gt;
#         Payroll Jobs: 16522&lt;br&gt;
#         Labor Force: 11478&lt;br&gt;
#         At least one vehicle (%): 53&lt;br&gt;
#         Vehicles to Households Ratio: 0.61&lt;br&gt;
#     &lt;/div&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_07dc2b48e1c97d34cd999b12964402d1 = L.marker(
#                 [42.3501, -71.1627],
#                 {}
#             ).addTo(map_9f8256a5e3db6afedc58da5df544ab58);
#
#
#             marker_07dc2b48e1c97d34cd999b12964402d1.bindTooltip(
#                 `&lt;div&gt;
#
#     &lt;div style=&quot;max-height: 300px; overflow-y: auto;&quot;&gt;
#         &lt;h4&gt;Brighton&lt;/h4&gt;
#         &lt;b&gt;Demographic Information:&lt;/b&gt;&lt;br&gt;
#         TotChild: 4244&lt;br&gt;
#         OlderAdult: 5847&lt;br&gt;
#         MedIllnes: 23936.8&lt;br&gt;
#         POC2: 19768&lt;br&gt;
#         LEP: 22914&lt;br&gt;
#         Low_to_No: 17067&lt;br&gt;
#         TotDis: 5502&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Environmental Information:&lt;/b&gt;&lt;br&gt;
#         NO2: 23.221051364365973&lt;br&gt;
#         O3: 20.08868378812199&lt;br&gt;
#         PM10: 26.907098715890843&lt;br&gt;
#         PM2.5: 10.012760834670946&lt;br&gt;
#         SO2: 0.2493338683788121&lt;br&gt;
#         AQI: 39.829454253611566&lt;br&gt;
#         Category: Good air quality&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Transportation Information:&lt;/b&gt;&lt;br&gt;
#         Bus Stops Count: 141&lt;br&gt;
#         Blue Bikes Stations Count: 18&lt;br&gt;
#         Blue Bikes Docks Count: 302&lt;br&gt;
#         &lt;br&gt;
#         &lt;b&gt;Health Information:&lt;/b&gt;&lt;br&gt;
#         CASTHMA CrudePrev: 10.5&lt;br&gt;
#         COPD CrudePrev: 3.5&lt;br&gt;
#         CHD CrudePrev: 3.2&lt;br&gt;
#         STROKE CrudePrev: 1.6&lt;br&gt;
#         HIGHCHOL CrudePrev: 24.3&lt;br&gt;
#         GHLTH CrudePrev: 8.9&lt;br&gt;
#         PHLTH CrudePrev: 6.5&lt;br&gt;
#         MHLTH CrudePrev: 16.2&lt;br&gt;
#         CSMOKING CrudePrev: 8.6&lt;br&gt;
#         BINGE CrudePrev: 22.3&lt;br&g
