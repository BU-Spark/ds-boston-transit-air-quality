# %%
import pandas as pd

# %%
df_2019 = pd.read_csv('Poverty-2019.csv')
df_2020 = pd.read_csv('Poverty-2020.csv')
df_2021 = pd.read_csv('Poverty-2021.csv')
df_2019
# Out:
#                               Label (Grouping)
# 0                                        Total  \
# 1                            Less than $10,000
# 2                           $10,000 to $14,999
# 3                           $15,000 to $24,999
# 4                           $25,000 to $34,999
# 5                           $35,000 to $49,999
# 6                           $50,000 to $74,999
# 7                           $75,000 to $99,999
# 8                         $100,000 to $149,999
# 9                         $150,000 to $199,999
# 10                            $200,000 or more
# 11                     Median income (dollars)
# 12                       Mean income (dollars)
# 13                           PERCENT ALLOCATED
# 14      Household income in the past 12 months
# 15         Family income in the past 12 months
# 16      Nonfamily income in the past 12 months
#
#    ZCTA5 02118!!Households!!Estimate ZCTA5 02118!!Households!!Margin of Error
# 0                             13,193                                     ±350  \
# 1                              13.3%                                     ±2.1
# 2                               7.3%                                     ±1.8
# 3                              10.2%                                     ±2.0
# 4                               5.2%                                     ±1.6
# 5                               5.9%                                     ±1.4
# 6                              10.8%                                     ±2.5
# 7                               6.7%                                     ±1.4
# 8                               8.9%                                     ±1.6
# 9                              10.3%                                     ±1.7
# 10                             21.4%                                     ±2.7
# 11                            67,805                                   ±9,324
# 12                           138,217                                  ±10,195
# 13                               NaN                                      NaN
# 14                             34.0%                                      (X)
# 15                               (X)                                      (X)
# 16                               (X)                                      (X)
#
#    ZCTA5 02118!!Families!!Estimate ZCTA5 02118!!Families!!Margin of Error
# 0                            5,380                                   ±342  \
# 1                             9.0%                                   ±2.5
# 2                             4.3%                                   ±1.8
# 3                             7.6%                                   ±2.4
# 4                             7.1%                                   ±2.5
# 5                             7.0%                                   ±1.9
# 6                             9.6%                                   ±3.2
# 7                             6.2%                                   ±2.4
# 8                             9.1%                                   ±2.4
# 9                             9.4%                                   ±2.9
# 10                           30.7%                                   ±4.4
# 11                          93,125                                ±30,898
# 12                         187,783                                ±20,884
# 13                             NaN                                    NaN
# 14                             (X)                                    (X)
# 15                           33.4%                                    (X)
# 16                             (X)                                    (X)
#
#    ZCTA5 02118!!Married-couple families!!Estimate
# 0                                           3,438  \
# 1                                            1.9%
# 2                                            2.7%
# 3                                            6.2%
# 4                                            3.1%
# 5                                            4.2%
# 6                                            6.3%
# 7                                            4.0%
# 8                                           13.4%
# 9                                           13.0%
# 10                                          45.1%
# 11                                        175,595
# 12                                              N
# 13                                            NaN
# 14                                            (X)
# 15                                            (X)
# 16                                            (X)
#
#    ZCTA5 02118!!Married-couple families!!Margin of Error
# 0                                                ±337     \
# 1                                                ±1.4
# 2                                                ±1.5
# 3                                                ±2.6
# 4                                                ±2.1
# 5                                                ±1.9
# 6                                                ±3.5
# 7                                                ±2.1
# 8                                                ±3.5
# 9                                                ±4.6
# 10                                               ±5.5
# 11                                            ±24,125
# 12                                                  N
# 13                                                NaN
# 14                                                (X)
# 15                                                (X)
# 16                                                (X)
#
#    ZCTA5 02118!!Nonfamily households!!Estimate
# 0                                        7,813  \
# 1                                        16.5%
# 2                                         9.1%
# 3                                        12.0%
# 4                                         3.9%
# 5                                         5.1%
# 6                                        11.6%
# 7                                         7.0%
# 8                                         9.3%
# 9                                        11.1%
# 10                                       14.4%
# 11                                      54,834
# 12                                     101,472
# 13                                         NaN
# 14                                         (X)
# 15                                         (X)
# 16                                       34.0%
#
#    ZCTA5 02118!!Nonfamily households!!Margin of Error
# 0                                                ±375  \
# 1                                                ±3.4
# 2                                                ±2.5
# 3                                                ±3.2
# 4                                                ±2.0
# 5                                                ±2.0
# 6                                                ±3.3
# 7                                                ±1.8
# 8                                                ±2.2
# 9                                                ±2.3
# 10                                               ±3.0
# 11                                             ±7,293
# 12                                            ±10,814
# 13                                                NaN
# 14                                                (X)
# 15                                                (X)
# 16                                                (X)
#
#    ZCTA5 02119!!Households!!Estimate  ...
# 0                             11,570  ...  \
# 1                              22.1%  ...
# 2                              10.6%  ...
# 3                              10.9%  ...
# 4                               8.8%  ...
# 5                              12.8%  ...
# 6                              11.1%  ...
# 7                               7.4%  ...
# 8                               9.4%  ...
# 9                               4.7%  ...
# 10                              2.3%  ...
# 11                            31,900  ...
# 12                            52,499  ...
# 13                               NaN  ...
# 14                             46.9%  ...
# 15                               (X)  ...
# 16                               (X)  ...
#
#    ZCTA5 02125!!Nonfamily households!!Estimate
# 0                                        6,271  \
# 1                                        17.9%
# 2                                        11.7%
# 3                                         9.7%
# 4                                         5.8%
# 5                                         8.7%
# 6                                        10.7%
# 7                                         6.8%
# 8                                        11.2%
# 9                                         9.3%
# 10                                        8.1%
# 11                                      42,940
# 12                                      74,768
# 13                                         NaN
# 14                                         (X)
# 15                                         (X)
# 16                                       37.3%
#
#    ZCTA5 02125!!Nonfamily households!!Margin of Error
# 0                                                ±431  \
# 1                                                ±3.1
# 2                                                ±2.4
# 3                                                ±2.5
# 4                                                ±1.9
# 5                                                ±2.4
# 6                                                ±2.4
# 7                                                ±2.0
# 8                                                ±2.6
# 9                                                ±2.5
# 10                                               ±2.5
# 11                                             ±5,398
# 12                                             ±8,094
# 13                                                NaN
# 14                                                (X)
# 15                                                (X)
# 16                                                (X)
#
#    ZCTA5 02215!!Households!!Estimate ZCTA5 02215!!Households!!Margin of Error
# 0                              7,845                                     ±326  \
# 1                              21.6%                                     ±3.0
# 2                               7.5%                                     ±2.7
# 3                               6.5%                                     ±1.7
# 4                               7.0%                                     ±2.0
# 5                               9.0%                                     ±2.6
# 6                              11.0%                                     ±2.3
# 7                               9.2%                                     ±2.1
# 8                              12.2%                                     ±2.1
# 9                               7.4%                                     ±1.8
# 10                              8.8%                                     ±2.4
# 11                            45,856                                   ±8,741
# 12                            81,199                                   ±8,272
# 13                               NaN                                      NaN
# 14                             26.4%                                      (X)
# 15                               (X)                                      (X)
# 16                               (X)                                      (X)
#
#    ZCTA5 02215!!Families!!Estimate ZCTA5 02215!!Families!!Margin of Error
# 0                            1,728                                   ±277  \
# 1                             5.1%                                   ±3.0
# 2                             9.4%                                   ±6.7
# 3                             3.9%                                   ±2.4
# 4                             6.9%                                   ±4.2
# 5                             8.0%                                   ±7.0
# 6                             8.7%                                   ±4.6
# 7                            10.5%                                   ±5.2
# 8                            12.5%                                   ±4.8
# 9                            12.7%                                   ±6.0
# 10                           22.3%                                   ±7.1
# 11                          96,356                                ±16,686
# 12                         137,990                                ±25,412
# 13                             NaN                                    NaN
# 14                             (X)                                    (X)
# 15                           36.2%                                    (X)
# 16                             (X)                                    (X)
#
#    ZCTA5 02215!!Married-couple families!!Estimate
# 0                                           1,300  \
# 1                                            2.3%
# 2                                            6.9%
# 3                                            2.9%
# 4                                            8.3%
# 5                                            3.0%
# 6                                            5.4%
# 7                                           11.2%
# 8                                           15.5%
# 9                                           16.0%
# 10                                          28.5%
# 11                                        128,553
# 12                                              N
# 13                                            NaN
# 14                                            (X)
# 15                                            (X)
# 16                                            (X)
#
#    ZCTA5 02215!!Married-couple families!!Margin of Error
# 0                                                ±213     \
# 1                                                ±2.2
# 2                                                ±6.1
# 3                                                ±2.3
# 4                                                ±5.3
# 5                                                ±2.3
# 6                                                ±3.1
# 7                                                ±5.2
# 8                                                ±6.3
# 9                                                ±7.4
# 10                                               ±9.8
# 11                                            ±33,960
# 12                                                  N
# 13                                                NaN
# 14                                                (X)
# 15                                                (X)
# 16                                                (X)
#
#    ZCTA5 02215!!Nonfamily households!!Estimate
# 0                                        6,117  \
# 1                                        26.4%
# 2                                         7.8%
# 3                                         6.2%
# 4                                         7.2%
# 5                                         9.3%
# 6                                        11.6%
# 7                                         8.6%
# 8                                        12.1%
# 9                                         5.9%
# 10                                        4.9%
# 11                                      39,590
# 12                                      64,937
# 13                                         NaN
# 14                                         (X)
# 15                                         (X)
# 16                                       23.5%
#
#    ZCTA5 02215!!Nonfamily households!!Margin of Error
# 0                                                ±343
# 1                                                ±3.6
# 2                                                ±3.1
# 3                                                ±1.9
# 4                                                ±2.2
# 5                                                ±2.7
# 6                                                ±2.8
# 7                                                ±2.4
# 8                                                ±2.5
# 9                                                ±1.7
# 10                                               ±2.3
# 11                                             ±4,104
# 12                                             ±7,767
# 13                                                NaN
# 14                                                (X)
# 15                                                (X)
# 16                                                (X)
#
# [17 rows x 41 columns]

# %%
zip_codes = set(col.split('!!')[0][-5:] for col in df_2019.columns if 'ZCTA5' in col)
metrics = []
cols = set(f'ZCTA5 {zip_code}!!{metric}' for zip_code in zip_codes for metric in metrics)
cols
# Out:
# set()
