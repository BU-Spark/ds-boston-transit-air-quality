# %%
import pandas as np 
import pandas as pd

# Load the data from CSV files
data_2019 = pd.read_csv('Median-Income2019.csv')
data_2020 = pd.read_csv('Median-Income2020.csv')
data_2021 = pd.read_csv('Median-Income2021.csv')

# Display the first few rows to confirm successful loading
data_2019.head(), data_2020.head(), data_2021.head()
# Out:
# (                          Label (Grouping) ZCTA5 02118!!Number!!Estimate  \
#  0                         HOUSEHOLD INCOME                           NaN
#  1                           All households                        13,193
#  2                            With earnings                        10,492
#  3              With wages or salary income                        10,235
#  4              With self-employment income                           997
#
#    ZCTA5 02118!!Number!!Margin of Error  \
#  0                                  NaN
#  1                                 ±350
#  2                                 ±398
#  3                                 ±404
#  4                                 ±192
#
#    ZCTA5 02118!!Percent Distribution!!Estimate  \
#  0                                         NaN
#  1                                      13,193
#  2                                       79.5%
#  3                                       77.6%
# ...
